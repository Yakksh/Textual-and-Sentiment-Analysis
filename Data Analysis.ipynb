# %%
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
import numpy as np
import spacy

# %%
# nltk.download('punkt')

# %%
articles = pd.read_excel('Articles.xlsx', index_col=0)
articles
# Out:
#                                                  Title  \
# 0              Is telehealth the future of healthcare?
# 1    How Telehealth and Telemedicine helping people...
# 2      Is telemedicine effective in treating patients?
# 3                    The Future of Telehealth Services
# 4    How are people diverted to Telehealth services...
# ..                                                 ...
# 145                            Blockchain for Payments
# 146                            The future of Investing
# 147                   Big Data Analytics in Healthcare
# 148      Business Analytics In The Healthcare Industry
# 149  Challenges and Opportunities of Big Data in He...
#
#                                                   Text
# 0    \n\nCovid-19 has paved the way for advancement...
# 1    \nThe last 2 years are the most critical time ...
# 2    \nTelemedicine, which allows patients and doct...
# 3    \nTelemedicine refers to a specific set of cli...
# 4    \nThe future of telehealth stays positive\nTo ...
# ..                                                 ...
# 145  \nReconciling with the financial realities of ...
# 146  \nWhat Is an Investment?\nAn investment is a r...
# 147  \nQuality and affordable healthcare is a visio...
# 148  \nAnalytics is a statistical scientific proces...
# 149  \nBig Data\nTo begin with I shall first like t...
#
# [150 rows x 2 columns]

# %%
data = pd.read_excel('input.xlsx')
data['URL']
# Out:
# 0      https://insights.blackcoffer.com/is-telehealth...
# 1      https://insights.blackcoffer.com/how-telehealt...
# 2      https://insights.blackcoffer.com/is-telemedici...
# 3      https://insights.blackcoffer.com/is-telehealth...
# 4      https://insights.blackcoffer.com/how-people-di...
#                              ...
# 145    https://insights.blackcoffer.com/blockchain-fo...
# 146    https://insights.blackcoffer.com/the-future-of...
# 147    https://insights.blackcoffer.com/big-data-anal...
# 148    https://insights.blackcoffer.com/business-anal...
# 149    https://insights.blackcoffer.com/challenges-an...
# Name: URL, Length: 150, dtype: object

# %%
df = pd.concat([data, articles['Text']], axis=1)
df
# Out:
#      URL_ID                                                URL  \
# 0       1.0  https://insights.blackcoffer.com/is-telehealth...
# 1       2.0  https://insights.blackcoffer.com/how-telehealt...
# 2       3.0  https://insights.blackcoffer.com/is-telemedici...
# 3       4.0  https://insights.blackcoffer.com/is-telehealth...
# 4       5.0  https://insights.blackcoffer.com/how-people-di...
# ..      ...                                                ...
# 145   146.0  https://insights.blackcoffer.com/blockchain-fo...
# 146   147.0  https://insights.blackcoffer.com/the-future-of...
# 147   148.0  https://insights.blackcoffer.com/big-data-anal...
# 148   149.0  https://insights.blackcoffer.com/business-anal...
# 149   150.0  https://insights.blackcoffer.com/challenges-an...
#
#                                                   Text
# 0    \n\nCovid-19 has paved the way for advancement...
# 1    \nThe last 2 years are the most critical time ...
# 2    \nTelemedicine, which allows patients and doct...
# 3    \nTelemedicine refers to a specific set of cli...
# 4    \nThe future of telehealth stays positive\nTo ...
# ..                                                 ...
# 145  \nReconciling with the financial realities of ...
# 146  \nWhat Is an Investment?\nAn investment is a r...
# 147  \nQuality and affordable healthcare is a visio...
# 148  \nAnalytics is a statistical scientific proces...
# 149  \nBig Data\nTo begin with I shall first like t...
#
# [150 rows x 3 columns]

# %%
text = df['Text']

# %%
ps = PorterStemmer()

# %%
corpus = []
for i in range(0,149):
    tx = re.sub('[^a-zA-Z]', ' ', text[i])
    tx = tx.lower()
    tx = tx.split()
    tx = [ps.stem(word) for word in tx if not word in set(stopwords.words('english'))]
    tx = ' '.join(tx)
    corpus.append(tx)

# %%
# corpus

# %%
with open('MasterDictionary/positive-words.txt' ,'r') as f:
    positive_dict = f.read()

with open('MasterDictionary/negative-words.txt' ,'r') as f:
    negative_dict = f.read()
positive_dict = positive_dict.split('\n')
negative_dict = negative_dict.split('\n')

# %%
with open('StopWords/StopWords_Auditor.txt', 'r') as f1, open('StopWords/StopWords_Currencies.txt', 'r') as f2, \
open('StopWords/StopWords_DatesandNumbers.txt', 'r') as f3, open('StopWords/StopWords_Generic.txt', 'r') as f4, \
open('StopWords/StopWords_GenericLong.txt', 'r') as f5, open('StopWords/StopWords_Geographic.txt', 'r') as f6, \
open('StopWords/StopWords_Names.txt', 'r') as f7:
    stopwords1 = f1.read()
    stopwords2 = f2.read()
    stopwords3 = f3.read()
    stopwords4 = f4.read()
    stopwords5 = f5.read()
    stopwords6 = f6.read()
    stopwords7 = f7.read()

# %%
stopwords1 = stopwords1.split('\n')

# %%
stopwords2 = stopwords2.replace('|', '\n').replace(' ','').split('\n')

# %%
stopwords3 = stopwords3.replace('|', '\n').replace(' ','').split('\n')

# %%
stopwords4 = stopwords4.split('\n')

# %%
stopwords5 = stopwords5.split('\n')

# %%
stopwords6 = stopwords6.replace('|', '\n').replace(' ', '').split('\n')

# %%
stopwords7 = stopwords7.split('\n')

# %%
stopwords = stopwords1+stopwords2+stopwords3+stopwords4+stopwords5+stopwords6+stopwords7

# %%
def tokenize(text):
    text = re.sub(r'[^A-Za-z]',' ',text.upper())
    tokenized_words = word_tokenize(text)
    return tokenized_words

def remove_stopwords(words, stop_words):
    return [x for x in words if x not in stop_words]

def positive_score(words, positive_dict):
    return len([x for x in words if x.lower() in positive_dict])

def negative_score(words, negative_dict):
    return len([x for x in words if x.lower() in negative_dict])

def polarity(positive_score, negative_score):
    return (positive_score - negative_score)/((positive_score + negative_score)+ 0.000001)

def subjectivity(positive_score, negative_score, num_words):
    return (positive_score+negative_score)/(num_words+ 0.000001)

def fog_index(average_sentence_length, percentage_complexwords):
    return 0.4*(average_sentence_length + percentage_complexwords)

def syllable_count(words):
    k = []
    for word in words:
        count = 0
        v = []
        d = {}
        if(word[-2:] == 'ES' or word[-2:] == 'ED'):
            count = count - 1
        for i in word:
            if i in "AEIOU":
                v.append(i)
                d[i] = d.get(i,0)+1
        for i in d:
            count = count + d[i]
        k.append(count)
            
    return k

def complex_word_count(syllable_count):
    count = 0
    for i in syllable_count:
        if i>2:
            count += 1
    return count

def char_count(words):
    count = 0
    for word in words:
        count += len(word)
    return count

# %%
def transform(text, stopwords):
    text = tokenize(text)
    return remove_stopwords(text, stopwords)

# %%
# Cleaning using Stopwords Lists
df['Transformed_text'] = df['Text'].apply(lambda tx: transform(tx, stopwords))

# %%
df['Positive Score'] = df['Transformed_text'].apply(lambda tx: positive_score(tx, positive_dict))

# %%
df['Negative Score'] = df['Transformed_text'].apply(lambda tx: negative_score(tx, negative_dict))

# %%
df['Polarity Score'] = (df['Positive Score']-df['Negative Score'])/((df['Positive Score']-df['Negative Score'])+0.000001)

# %%
df['Subjectivity Score'] = (df['Positive Score']-df['Negative Score'])/(len(df['Transformed_text']) + 0.000001)

# %%
df['Word Count'] = df['Transformed_text'].apply(lambda x: len(str(x).split()))

# %%
df['Syllable per Word'] = df['Transformed_text'].apply(lambda words: syllable_count(words))

# %%
df['Complex Word Count'] = df['Syllable per Word'].apply(lambda syllable: complex_word_count(syllable))

# %%
df['sentence length'] = np.nan
df['Avg Sentence Length'] = np.nan
df['Percentage of Complex Words'] = np.nan
df['Fog Index'] = np.nan

for i in range(0,len(df)):
    
    df['sentence length'][i]  =   len(nltk.sent_tokenize(df['Text'][i]))
    df['Avg Sentence Length'][i] = len(nltk.word_tokenize(df['Text'][i]))/df['sentence length'][i]
    df['Percentage of Complex Words'][i] = df['Complex Word Count'][i]/df['Word Count'][i] 
    df['Fog Index'][i] = 0.4 * (df['Avg Sentence Length'][i] + df['Percentage of Complex Words'][i])
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_19300/1545829722.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sentence length'][i]  =   len(nltk.sent_tokenize(df['Text'][i]))
# C:\Users\user\AppData\Local\Temp/ipykernel_19300/1545829722.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Avg Sentence Length'][i] = len(nltk.word_tokenize(df['Text'][i]))/df['sentence length'][i]
# C:\Users\user\AppData\Local\Temp/ipykernel_19300/1545829722.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Percentage of Complex Words'][i] = df['Complex Word Count'][i]/df['Word Count'][i]
# C:\Users\user\AppData\Local\Temp/ipykernel_19300/1545829722.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Fog Index'][i] = 0.4 * (df['Avg Sentence Length'][i] + df['Percentage of Complex Words'][i])

# %%
df['Avg Number of Words Per Sentence'] = np.nan
for i in range(0,len(df)):
    df['Avg Number of Words Per Sentence'][i] = df['Word Count'][i]/len(nltk.sent_tokenize(df['Text'][i]))
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_19300/2925480799.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Avg Number of Words Per Sentence'][i] = df['Word Count'][i]/len(nltk.sent_tokenize(df['Text'][i]))

# %%
df['chara_count'] = df['Transformed_text'].apply(lambda words: char_count(words))

# %%
df['Avg Word Length'] = np.nan
for i in range(0,len(df)):
    df['Avg Word Length'][i] = df['chara_count'][i]/df['Word Count'][i]
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_19300/3878996883.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Avg Word Length'][i] = df['chara_count'][i]/df['Word Count'][i]

# %%
nlp = spacy.load('en_core_web_sm')

# %%
df['Personal Pronouns'] = np.nan

for i in range(len(df)):
    doc = nlp(df['Text'][i])
    tok = []
    for token in doc:
        if token.pos_ == 'PRON':
            tok.append(token)
        
    df['Personal Pronouns'][i] = tok
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_19300/2961243990.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Personal Pronouns'][i] = tok
# C:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
df = df.drop(columns=['sentence length', 'chara_count', 'Text', 'Transformed_text'])

# %%
df = df[['URL_ID', 'URL', 'Positive Score', 'Negative Score', 'Polarity Score', 'Subjectivity Score', 'Avg Sentence Length', \
    'Percentage of Complex Words', 'Fog Index', 'Avg Number of Words Per Sentence', 'Complex Word Count', 'Word Count', \
   'Syllable per Word', 'Personal Pronouns', 'Avg Word Length']]

# %%
df
# Out:
#      URL_ID                                                URL  \
# 0       1.0  https://insights.blackcoffer.com/is-telehealth...
# 1       2.0  https://insights.blackcoffer.com/how-telehealt...
# 2       3.0  https://insights.blackcoffer.com/is-telemedici...
# 3       4.0  https://insights.blackcoffer.com/is-telehealth...
# 4       5.0  https://insights.blackcoffer.com/how-people-di...
# ..      ...                                                ...
# 145   146.0  https://insights.blackcoffer.com/blockchain-fo...
# 146   147.0  https://insights.blackcoffer.com/the-future-of...
# 147   148.0  https://insights.blackcoffer.com/big-data-anal...
# 148   149.0  https://insights.blackcoffer.com/business-anal...
# 149   150.0  https://insights.blackcoffer.com/challenges-an...
#
#      Positive Score  Negative Score  Polarity Score  Subjectivity Score  \
# 0                43               8        1.000000            0.233333
# 1                40              16        1.000000            0.160000
# 2                87              28        1.000000            0.393333
# 3                66              22        1.000000            0.293333
# 4                84              33        1.000000            0.340000
# ..              ...             ...             ...                 ...
# 145              28              29        1.000001           -0.006667
# 146              43              15        1.000000            0.186667
# 147              32              47        1.000000           -0.100000
# 148              37               7        1.000000            0.200000
# 149              45              40        1.000000            0.033333
#
#      Avg Sentence Length  Percentage of Complex Words  Fog Index  \
# 0              29.840000                     0.552972  12.157189
# 1              19.629630                     0.508230   8.055144
# 2              21.215054                     0.537229   8.700913
# 3              23.459770                     0.527125   9.594758
# 4              25.600000                     0.527885  10.451154
# ..                   ...                          ...        ...
# 145            20.673469                     0.392453   8.426369
# 146            28.451613                     0.422383  11.549598
# 147            19.636364                     0.471014   8.042951
# 148            27.275862                     0.548694  11.129822
# 149            17.424242                     0.410256   7.133800
#
#      Avg Number of Words Per Sentence  Complex Word Count  Word Count  \
# 0                           15.480000                 214         387
# 1                            9.000000                 247         486
# 2                           11.408602                 570        1061
# 3                           12.712644                 583        1106
# 4                           13.000000                 549        1040
# ..                                ...                 ...         ...
# 145                         10.816327                 208         530
# 146                         13.403226                 351         831
# 147                         10.454545                 325         690
# 148                         14.517241                 231         421
# 149                          8.863636                 240         585
#
#                                      Syllable per Word  \
# 0    [2, 1, 4, 4, 2, 2, 3, 1, 4, 3, 4, 2, 3, 3, 2, ...
# 1    [1, 2, 3, 2, 1, 3, 2, 0, 1, 2, 3, 3, 3, 3, 1, ...
# 2    [6, 2, 3, 2, 5, 3, 2, 5, 2, 5, 4, 3, 3, 3, 3, ...
# 3    [6, 2, 1, 3, 1, 3, 3, 4, 3, 1, 2, 3, 4, 2, 2, ...
# 4    [3, 4, 1, 4, 2, 2, 3, 4, 3, 1, 2, 3, 3, 2, 6, ...
# ..                                                 ...
# 145  [4, 4, 4, 1, 5, 2, 2, 0, 1, 2, 1, 1, 0, 1, 2, ...
# 146  [3, 3, 1, 4, 1, 2, 4, 3, 1, 6, 5, 3, 1, 2, 2, ...
# 147  [3, 4, 4, 1, 3, 3, 2, 2, 1, 3, 3, 1, 4, 5, 4, ...
# 148  [3, 1, 4, 4, 2, 4, 3, 4, 2, 2, 2, 3, 3, 2, 1, ...
# 149  [1, 2, 2, 1, 2, 3, 1, 2, 3, 3, 1, 1, 2, 1, 2, ...
#
#                                      Personal Pronouns  Avg Word Length
# 0    [its, their, them, them, them, everyone, they,...         7.248062
# 1    [it, they, their, their, their, they, their, t...         6.681070
# 2    [their, their, them, who, who, their, It, thei...         7.227144
# 3    [them, it, It, their, their, they, who, their,...         7.089512
# 4    [everything, they, it, What, What, It, they, t...         7.372115
# ..                                                 ...              ...
# 145  [There, ’s, my, I, It, me, I, my, who, who, it...         6.658491
# 146  [What, one, something, its, its, its, what, An...         6.540313
# 147  [it, everyone, he, she, it, It, my, He, he, It...         6.491304
# 148  [itself, their, your, their, them, it, what, T...         7.541568
# 149  [I, what, it, our, it, them, It, we, it, it, t...         6.661538
#
# [150 rows x 15 columns]

# %%
df.to_excel('Output Data Structure.xlsx')
